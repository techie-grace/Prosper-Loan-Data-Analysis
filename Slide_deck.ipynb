# %% [markdown]
# # Part II - (Prosper Loan Analysis Prediction )
# ## by (Amazing-Grace Umoren)

# %% [markdown]
# ## Investigation Overview
#
#
# > This Presentation works through details about customers
#
#
#
#
# ## Dataset Overview
#
# > The Prosper Loan Dataset has 113937 rows and 81 column, containing information on the loan and customers. Some features contained in the data includes: Borrowers Rate, Occupation, Number of Credit Line, Credit Score etc.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
data = pd.read_csv("prosperLoanData.csv")

# %% [markdown]
# ## Customer Location
#
# > The chart below shows the states with the highest number of Loans. With California being the Highest state.

# %%
plt.figure(figsize=(18,9))
sns.countplot(x='BorrowerState', data=data, palette='Blues_r' ,order=data['BorrowerState'].value_counts().index)
plt.xlabel("State")
plt.ylabel("Count")
plt.title("Customer Demographic");

# %% [markdown]
# ## Customers Who are Home Owners
#
# > A higher number of customers are home owners as seen below.

# %%
#Explore how many home owners there are

plt.figure(figsize=(18,9))
ax = sns.countplot(x='IsBorrowerHomeowner', data=data, palette='Blues_r')
for container in ax.containers:
            ax.bar_label(container)


plt.xlabel("Is Home Owner?")
plt.ylabel("Count")
plt.title("Is Customer Home Owner ?");

# %% [markdown]
# ## Income Range of Customers
#
# > Most Borrowers had an income between $25,000-49,999 dollars

# %%
#clean the Income Range column and change Not employed to $0 and Not displayed to NaN

data.IncomeRange.replace({'Not employed':'$0','Not displayed':np.nan}, inplace=True)


#plot chart
order = ['$0', '$1-24,999','$25,000-49,999', '$50,000-74,999', '$75,000-99,999', '$100,000+']

plt.figure(figsize=(18,9))
sns.countplot(x='IncomeRange', data=data, order=order)
plt.xlabel('Income Range')
plt.ylabel('Count')
plt.title('Customers Income Range');

# %%
# !jupyter nbconvert Slide_deck.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# ^C
